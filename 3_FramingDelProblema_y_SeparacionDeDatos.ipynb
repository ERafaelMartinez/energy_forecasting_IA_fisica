# %% [markdown]
# # 3. Framing del problema y separación del dataset

# %%
import pandasql as ps
import pandas as pd
import numpy as np
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### Lectura de los datos

# %%
data = pd.read_csv('./data_ordered.csv')
data = data.drop(columns = ['Unnamed: 0'])
data
# Out:
#          building_id            timestamp  electricity  site_id  square_feet  \
# 0               1447  2016-01-01 01:00:00      156.650       15        29775
# 1               1447  2016-01-01 02:00:00      157.575       15        29775
# 2               1447  2016-01-01 03:00:00      154.925       15        29775
# 3               1447  2016-01-01 04:00:00      156.075       15        29775
# 4               1447  2016-01-01 05:00:00      154.500       15        29775
# ...              ...                  ...          ...      ...          ...
# 1229003            6  2016-12-31 19:00:00      264.970        0        27926
# 1229004            6  2016-12-31 20:00:00      265.379        0        27926
# 1229005            6  2016-12-31 21:00:00      263.741        0        27926
# 1229006            6  2016-12-31 22:00:00      258.827        0        27926
# 1229007            6  2016-12-31 23:00:00      259.646        0        27926
#
#          air_temperature  dew_temperature  sea_level_pressure  wind_direction  \
# 0                    0.0        -2.000000              1019.4               7
# 1                    0.0        -2.000000              1019.4               7
# 2                    0.0        -2.000000              1019.4               0
# 3                    0.0        -2.111111              1019.4               7
# 4                    0.0        -2.222222              1019.4               7
# ...                  ...              ...                 ...             ...
# 1229003             22.8        10.000000              1021.7               3
# 1229004             23.3         8.900000              1021.0               4
# 1229005             23.3        10.000000              1021.1               3
# 1229006             22.8        10.000000              1021.1               4
# 1229007             20.6        10.000000              1021.1               0
#
#          wind_speed  pressure_meter  month  day  weekday  hour
# 0          4.100000             1.0      1    1        5     1
# 1          2.600000             1.0      1    1        6     2
# 2          2.100000             1.0      1    1        7     3
# 3          2.155556             1.0      1    1        1     4
# 4          2.211111             1.0      1    1        2     5
# ...             ...             ...    ...  ...      ...   ...
# 1229003    5.700000             1.0     12   31        6    19
# 1229004    4.100000             1.0     12   31        7    20
# 1229005    4.100000             1.0     12   31        1    21
# 1229006    3.100000             1.0     12   31        2    22
# 1229007    0.000000             1.0     12   31        3    23
#
# [1229008 rows x 15 columns]

# %% [markdown]
# Para este punto el timestamp ya no es necesario tenerlo, pues los datos ya están ordenados y los atributos del dataframe contienen la información del tiempo al igual que el id del sitio. Por tanto dejamos atrás dicha información.

# %%
data = data.drop(columns=['timestamp', 'site_id'])

# %% [markdown]
# Se extrae la lista de los edificios que contiene el dataset

# %%
buildings_id = ps.sqldf("select building_id from data group by building_id")
buildings_id
# Out:
#      building_id
# 0              6
# 1             12
# 2             27
# 3             33
# 4             34
# ..           ...
# 140         1422
# 141         1423
# 142         1424
# 143         1440
# 144         1447
#
# [145 rows x 1 columns]

# %% [markdown]
# Contamos con 145 edificios diferentes de uso residencial. Como se analizó en los notebooks anteriores, están distribuidos alrededor de distintas locaciones por lo que cada uno tiene condiciones climaticas diferentes asociadas.

# %% [markdown]
# ## 3.1 Framing del problema

# %% [markdown]
# Es en esta parte en donde se vuelve importante tener claro el problema para el cual queremos entrenar a nuestra red que aprenda, pues la forma que se le den a los datos a continuación, debe ser de tal forma que dicho objetivo sea alcanzable.
#
# El problema para el cual entrenaremos a nuestro sistema es para predecir el consumo eléctrico promedio de 1 hora en adelante, dada la información de consumo de las 12 horas anteriores, así como los datos climaticos y del tiempo de las 12 horas previas.
#
# Para dicho propósito, reformaremos la tabla que presentamos arriba de manera que agreguemos para cada edificio las horas anteriores en forma de columnas para los valores del clima y del consumo. Y hasta la derecha, quedará como variable objetivo el consumo al momento presente.

# %%
 # convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    #df = pd.DataFrame(data)
    df = data
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(data.shift(i))
        names += [('{}(t-{})'.format(j, i)) for j in data.columns]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('{}(t)'.format(j)) for j in data.columns]
        else:
            names += [('{}(t+{})'.format(j, i)) for j in data.columns]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

def weather_supervised(dataframe, n_in, n_out):
    df = dataframe.copy()
    df.pop('electricity')
    return series_to_supervised(data = df, n_in = n_in, n_out = n_out, dropnan=True)

def electric_supervised(dataframe, n_in, n_out):
    elec = pd.DataFrame(dataframe['electricity'])
    elec_sup = series_to_supervised(data = elec, n_in = n_in, n_out = n_out, dropnan=True)
    return elec_sup

# %%
framed_data = pd.DataFrame()
for id_ in buildings_id['building_id'].values:
    print('Framing data from builing id:', id_)
    building_data = ps.sqldf("select * from data where building_id = {}".format(id_))
    id_df = pd.DataFrame(building_data['building_id'])
    building_data.pop('building_id')
    building_electricity = electric_supervised(building_data, 6, 1)
    building_weather = weather_supervised(building_data, 6, 0)
    building_data = building_weather.join(building_electricity)
    building_data = id_df.join(building_data)
    building_data = building_data.dropna()
    
    framed_data = pd.concat([framed_data, building_data])
# Out:
# Framing data from builing id: 6
# Framing data from builing id: 12
# Framing data from builing id: 27
# Framing data from builing id: 33
# Framing data from builing id: 34
# Framing data from builing id: 35
# Framing data from builing id: 36
# Framing data from builing id: 37
# Framing data from builing id: 49
# Framing data from builing id: 56
# Framing data from builing id: 57
# Framing data from builing id: 58
# Framing data from builing id: 61
# Framing data from builing id: 62
# Framing data from builing id: 63
# Framing data from builing id: 64
# Framing data from builing id: 65
# Framing data from builing id: 66
# Framing data from builing id: 67
# Framing data from builing id: 77
# Framing data from builing id: 85
# Framing data from builing id: 90
# Framing data from builing id: 95
# Framing data from builing id: 96
# Framing data from builing id: 97
# Framing data from builing id: 98
# Framing data from builing id: 100
# Framing data from builing id: 127
# Framing data from builing id: 128
# Framing data from builing id: 129
# Framing data from builing id: 130
# Framing data from builing id: 131
# Framing data from builing id: 132
# Framing data from builing id: 133
# Framing data from builing id: 134
# Framing data from builing id: 135
# Framing data from builing id: 136
# Framing data from builing id: 166
# Framing data from builing id: 167
# Framing data from builing id: 202
# Framing data from builing id: 203
# Framing data from builing id: 204
# Framing data from builing id: 205
# Framing data from builing id: 215
# Framing data from builing id: 225
# Framing data from builing id: 228
# Framing data from builing id: 239
# Framing data from builing id: 240
# Framing data from builing id: 286
# Framing data from builing id: 342
# Framing data from builing id: 345
# Framing data from builing id: 357
# Framing data from builing id: 374
# Framing data from builing id: 436
# Framing data from builing id: 449
# Framing data from builing id: 478
# Framing data from builing id: 512
# Framing data from builing id: 517
# Framing data from builing id: 533
# Framing data from builing id: 541
# Framing data from builing id: 578
# Framing data from builing id: 581
# Framing data from builing id: 614
# Framing data from builing id: 647
# Framing data from builing id: 671
# Framing data from builing id: 749
# Framing data from builing id: 756
# Framing data from builing id: 758
# Framing data from builing id: 759
# Framing data from builing id: 771
# Framing data from builing id: 773
# Framing data from builing id: 774
# Framing data from builing id: 777
# Framing data from builing id: 779
# Framing data from builing id: 781
# Framing data from builing id: 787
# Framing data from builing id: 875
# Framing data from builing id: 878
# Framing data from builing id: 885
# Framing data from builing id: 887
# Framing data from builing id: 905
# Framing data from builing id: 906
# Framing data from builing id: 927
# Framing data from builing id: 932
# Framing data from builing id: 936
# Framing data from builing id: 937
# Framing data from builing id: 938
# Framing data from builing id: 939
# Framing data from builing id: 940
# Framing data from builing id: 941
# Framing data from builing id: 942
# Framing data from builing id: 949
# Framing data from builing id: 963
# Framing data from builing id: 965
# Framing data from builing id: 971
# Framing data from builing id: 1025
# Framing data from builing id: 1026
# Framing data from builing id: 1027
# Framing data from builing id: 1070
# Framing data from builing id: 1076
# Framing data from builing id: 1091
# Framing data from builing id: 1100
# Framing data from builing id: 1124
# Framing data from builing id: 1154
# Framing data from builing id: 1184
# Framing data from builing id: 1186
# Framing data from builing id: 1203
# Framing data from builing id: 1222
# Framing data from builing id: 1280
# Framing data from builing id: 1305
# Framing data from builing id: 1306
# Framing data from builing id: 1307
# Framing data from builing id: 1308
# Framing data from builing id: 1309
# Framing data from builing id: 1310
# Framing data from builing id: 1311
# Framing data from builing id: 1312
# Framing data from builing id: 1358
# Framing data from builing id: 1365
# Framing data from builing id: 1395
# Framing data from builing id: 1396
# Framing data from builing id: 1398
# Framing data from builing id: 1399
# Framing data from builing id: 1400
# Framing data from builing id: 1401
# Framing data from builing id: 1402
# Framing data from builing id: 1403
# Framing data from builing id: 1404
# Framing data from builing id: 1405
# Framing data from builing id: 1406
# Framing data from builing id: 1407
# Framing data from builing id: 1409
# Framing data from builing id: 1412
# Framing data from builing id: 1413
# Framing data from builing id: 1414
# Framing data from builing id: 1415
# Framing data from builing id: 1416
# Framing data from builing id: 1417
# Framing data from builing id: 1418
# Framing data from builing id: 1419
# Framing data from builing id: 1422
# Framing data from builing id: 1423
# Framing data from builing id: 1424
# Framing data from builing id: 1440
# Framing data from builing id: 1447

# %% [markdown]
# Se obtiene el dataframe con los datos ya formateados. Sin embargo se notó posteriormente que una cantidad considerable de edificios tenía más del 40% de los valores de la electricidad en 0, por lo que a continuación se remueven del dataframe obtenido previamente.

# %%
framed_data
# Out:
#       building_id  square_feet(t-6)  air_temperature(t-6)  \
# 6               6           27926.0                  25.0
# 7               6           27926.0                  24.4
# 8               6           27926.0                  22.8
# 9               6           27926.0                  21.1
# 10              6           27926.0                  20.0
# ...           ...               ...                   ...
# 7465         1447           29775.0                  -3.3
# 7466         1447           29775.0                  -2.8
# 7467         1447           29775.0                  -1.7
# 7468         1447           29775.0                  -0.6
# 7469         1447           29775.0                   2.2
#
#       dew_temperature(t-6)  sea_level_pressure(t-6)  wind_direction(t-6)  \
# 6                     20.0                   1019.7                  0.0
# 7                     21.1                   1020.2                  2.0
# 8                     21.1                   1020.2                  0.0
# 9                     20.6                   1020.1                  0.0
# 10                    20.0                   1020.0                  6.0
# ...                    ...                      ...                  ...
# 7465                  -7.8                   1014.4                  4.0
# 7466                  -7.8                   1013.4                  4.0
# 7467                  -7.2                   1012.3                  4.0
# 7468                  -6.7                   1011.1                  4.0
# 7469                  -7.8                   1009.1                  4.0
#
#       wind_speed(t-6)  pressure_meter(t-6)  month(t-6)  day(t-6)  ...  \
# 6                 0.0                  1.0         1.0       1.0  ...
# 7                 1.5                  1.0         1.0       1.0  ...
# 8                 0.0                  1.0         1.0       1.0  ...
# 9                 0.0                  1.0         1.0       1.0  ...
# 10                2.6                  1.0         1.0       1.0  ...
# ...               ...                  ...         ...       ...  ...
# 7465              6.7                  1.0        12.0      31.0  ...
# 7466              5.7                  1.0        12.0      31.0  ...
# 7467              6.7                  1.0        12.0      31.0  ...
# 7468              7.2                  1.0        12.0      31.0  ...
# 7469              7.7                  1.0        12.0      31.0  ...
#
#       day(t-1)  weekday(t-1)  hour(t-1)  electricity(t-6)  electricity(t-5)  \
# 6          1.0           3.0        5.0             0.000             0.000
# 7          1.0           4.0        6.0             0.000             0.000
# 8          1.0           5.0        7.0             0.000             0.000
# 9          1.0           6.0        8.0             0.000             0.000
# 10         1.0           7.0        9.0             0.000             0.000
# ...        ...           ...        ...               ...               ...
# 7465      31.0           4.0       18.0           145.750           146.050
# 7466      31.0           5.0       19.0           146.050           146.525
# 7467      31.0           6.0       20.0           146.525           152.725
# 7468      31.0           7.0       21.0           152.725           167.725
# 7469      31.0           1.0       22.0           167.725           170.225
#
#       electricity(t-4)  electricity(t-3)  electricity(t-2)  electricity(t-1)  \
# 6                0.000             0.000             0.000             0.000
# 7                0.000             0.000             0.000             0.000
# 8                0.000             0.000             0.000             0.000
# 9                0.000             0.000             0.000             0.000
# 10               0.000             0.000             0.000             0.000
# ...                ...               ...               ...               ...
# 7465           146.525           152.725           167.725           170.225
# 7466           152.725           167.725           170.225           167.800
# 7467           167.725           170.225           167.800           168.150
# 7468           170.225           167.800           168.150           164.075
# 7469           167.800           168.150           164.075           158.800
#
#       electricity(t)
# 6              0.000
# 7              0.000
# 8              0.000
# 9              0.000
# 10             0.000
# ...              ...
# 7465         167.800
# 7466         168.150
# 7467         164.075
# 7468         158.800
# 7469         159.575
#
# [1228138 rows x 74 columns]

# %%
#lista de id de edificios que tienen más del 10% de los datos en 0.
dirty = [90,64,37,36,98,34,49,62,27,85,77,6,67,66,56,57,58,61,100,65,35,33,63,95,97,12,96]
dirty = pd.DataFrame(data = dirty, columns = ['building_id'])

# %%
framed_data_clean = ps.sqldf("select * from framed_data where building_id not in (select building_id from dirty) ")

# %% [markdown]
# Se obtiene finalmente el dataframe con los datos a utilizar. A continuación sigue dividir los datos en los conjuntos de entrenamiento, validación y prueba.

# %%
framed_data_clean
# Out:
#         building_id  square_feet(t-6)  air_temperature(t-6)  \
# 0               127           27071.0                   3.8
# 1               127           27071.0                   3.7
# 2               127           27071.0                   2.6
# 3               127           27071.0                   2.0
# 4               127           27071.0                   2.3
# ...             ...               ...                   ...
# 991127         1447           29775.0                  -3.3
# 991128         1447           29775.0                  -2.8
# 991129         1447           29775.0                  -1.7
# 991130         1447           29775.0                  -0.6
# 991131         1447           29775.0                   2.2
#
#         dew_temperature(t-6)  sea_level_pressure(t-6)  wind_direction(t-6)  \
# 0                        2.4                   1020.9                  5.0
# 1                        2.4                   1021.6                  5.0
# 2                        1.9                   1021.9                  0.0
# 3                        1.2                   1022.3                  4.0
# 4                        1.8                   1022.7                  2.0
# ...                      ...                      ...                  ...
# 991127                  -7.8                   1014.4                  4.0
# 991128                  -7.8                   1013.4                  4.0
# 991129                  -7.2                   1012.3                  4.0
# 991130                  -6.7                   1011.1                  4.0
# 991131                  -7.8                   1009.1                  4.0
#
#         wind_speed(t-6)  pressure_meter(t-6)  month(t-6)  day(t-6)  ...  \
# 0                   3.1                  1.0         1.0       1.0  ...
# 1                   2.6                  1.0         1.0       1.0  ...
# 2                   0.0                  1.0         1.0       1.0  ...
# 3                   1.5                  1.0         1.0       1.0  ...
# 4                   1.5                  1.0         1.0       1.0  ...
# ...                 ...                  ...         ...       ...  ...
# 991127              6.7                  1.0        12.0      31.0  ...
# 991128              5.7                  1.0        12.0      31.0  ...
# 991129              6.7                  1.0        12.0      31.0  ...
# 991130              7.2                  1.0        12.0      31.0  ...
# 991131              7.7                  1.0        12.0      31.0  ...
#
#         day(t-1)  weekday(t-1)  hour(t-1)  electricity(t-6)  electricity(t-5)  \
# 0            1.0           2.0        5.0            8.6786           17.3571
# 1            1.0           3.0        6.0           17.3571           17.3571
# 2            1.0           4.0        7.0           17.3571           17.3571
# 3            1.0           5.0        8.0           17.3571           17.3571
# 4            1.0           6.0        9.0           17.3571           17.3571
# ...          ...           ...        ...               ...               ...
# 991127      31.0           4.0       18.0          145.7500          146.0500
# 991128      31.0           5.0       19.0          146.0500          146.5250
# 991129      31.0           6.0       20.0          146.5250          152.7250
# 991130      31.0           7.0       21.0          152.7250          167.7250
# 991131      31.0           1.0       22.0          167.7250          170.2250
#
#         electricity(t-4)  electricity(t-3)  electricity(t-2)  \
# 0                17.3571           17.3571           17.3571
# 1                17.3571           17.3571           17.3571
# 2                17.3571           17.3571           17.3571
# 3                17.3571           17.3571           17.3571
# 4                17.3571           17.3571           17.3571
# ...                  ...               ...               ...
# 991127          146.5250          152.7250          167.7250
# 991128          152.7250          167.7250          170.2250
# 991129          167.7250          170.2250          167.8000
# 991130          170.2250          167.8000          168.1500
# 991131          167.8000          168.1500          164.0750
#
#         electricity(t-1)  electricity(t)
# 0                17.3571         17.3571
# 1                17.3571         17.3571
# 2                17.3571         17.3571
# 3                17.3571         17.3571
# 4                17.3571         17.3571
# ...                  ...             ...
# 991127          170.2250        167.8000
# 991128          167.8000        168.1500
# 991129          168.1500        164.0750
# 991130          164.0750        158.8000
# 991131          158.8000        159.5750
#
# [991132 rows x 74 columns]

# %%
framed_data_clean.to_csv('./framed_data.csv')

# %% [markdown]
# ## 3.2 Separación del conjunto de datos

# %% [markdown]
# Dado que se tiene la información para diversos edicicios, el conjunto de entrenamiento consiste en la información para el 75% del total, tomamos 20% de validación y 5% del conjunto de prueba.

# %%
#obtenemos la lista de los edificios con los que se cuenta
id_s = ps.sqldf("select building_id from framed_data_clean group by building_id")

# %%
#separación de los id_s en entrenamiento, validación y prueba
n_train = int(0.75*len(id_s['building_id'].values))
n_val = int(0.20*len(id_s['building_id'].values))
n_test = int(0.05*len(id_s['building_id'].values))

id_s_sorted = np.sort(id_s['building_id'].values)
train_id_s = id_s_sorted[:n_train]
val_id_s = id_s_sorted[n_train:n_train + n_val]
test_id_s = id_s_sorted[n_train + n_val:]

print(train_id_s.shape, val_id_s.shape, test_id_s.shape)
# Out:
# (88,) (23,) (7,)

# %% [markdown]
# De tal forma, la separación resulta en 88 edificios para el entrenamiento, 23 para validación y 7 para prueba.

# %%
#dataframes con los id_s correspondientes
train_id_df = pd.DataFrame(data = train_id_s, columns = ['building_id'])
val_id_df = pd.DataFrame(data = val_id_s, columns = ['building_id'])
test_id_df = pd.DataFrame(data = test_id_s, columns = ['building_id'])

# %%
#separación del dataframe con la información completa para obtener dataframes 
#con la información de cada uno de los conjuntos.

train_data = ps.sqldf("select * from framed_data_clean where building_id in (select building_id from train_id_df)")
val_id_df = ps.sqldf("select * from framed_data_clean where building_id in (select building_id from val_id_df)")
test_id_df = ps.sqldf("select * from framed_data_clean where building_id in (select building_id from test_id_df)")

# %%
train_data
# Out:
#         building_id  square_feet(t-6)  air_temperature(t-6)  \
# 0               127           27071.0                   3.8
# 1               127           27071.0                   3.7
# 2               127           27071.0                   2.6
# 3               127           27071.0                   2.0
# 4               127           27071.0                   2.3
# ...             ...               ...                   ...
# 765834         1310           57274.0                  -2.8
# 765835         1310           57274.0                  -1.1
# 765836         1310           57274.0                   0.6
# 765837         1310           57274.0                   2.8
# 765838         1310           57274.0                   4.4
#
#         dew_temperature(t-6)  sea_level_pressure(t-6)  wind_direction(t-6)  \
# 0                        2.4                   1020.9                  5.0
# 1                        2.4                   1021.6                  5.0
# 2                        1.9                   1021.9                  0.0
# 3                        1.2                   1022.3                  4.0
# 4                        1.8                   1022.7                  2.0
# ...                      ...                      ...                  ...
# 765834                  -7.8                   1020.4                  4.0
# 765835                  -6.1                   1020.5                  4.0
# 765836                  -5.6                   1020.3                  4.0
# 765837                  -6.1                   1019.4                  4.0
# 765838                  -7.2                   1018.3                  4.0
#
#         wind_speed(t-6)  pressure_meter(t-6)  month(t-6)  day(t-6)  ...  \
# 0                   3.1                  1.0         1.0       1.0  ...
# 1                   2.6                  1.0         1.0       1.0  ...
# 2                   0.0                  1.0         1.0       1.0  ...
# 3                   1.5                  1.0         1.0       1.0  ...
# 4                   1.5                  1.0         1.0       1.0  ...
# ...                 ...                  ...         ...       ...  ...
# 765834              1.5                  1.0        12.0      31.0  ...
# 765835              2.6                  1.0        12.0      31.0  ...
# 765836              2.6                  1.0        12.0      31.0  ...
# 765837              5.1                  1.0        12.0      31.0  ...
# 765838              7.2                  1.0        12.0      31.0  ...
#
#         day(t-1)  weekday(t-1)  hour(t-1)  electricity(t-6)  electricity(t-5)  \
# 0            1.0           2.0        5.0            8.6786           17.3571
# 1            1.0           3.0        6.0           17.3571           17.3571
# 2            1.0           4.0        7.0           17.3571           17.3571
# 3            1.0           5.0        8.0           17.3571           17.3571
# 4            1.0           6.0        9.0           17.3571           17.3571
# ...          ...           ...        ...               ...               ...
# 765834      31.0           6.0       18.0           10.3900           11.6100
# 765835      31.0           7.0       19.0           11.6100            9.6600
# 765836      31.0           1.0       20.0            9.6600            8.8900
# 765837      31.0           2.0       21.0            8.8900           11.1000
# 765838      31.0           3.0       22.0           11.1000            9.1400
#
#         electricity(t-4)  electricity(t-3)  electricity(t-2)  \
# 0                17.3571           17.3571           17.3571
# 1                17.3571           17.3571           17.3571
# 2                17.3571           17.3571           17.3571
# 3                17.3571           17.3571           17.3571
# 4                17.3571           17.3571           17.3571
# ...                  ...               ...               ...
# 765834            9.6600            8.8900           11.1000
# 765835            8.8900           11.1000            9.1400
# 765836           11.1000            9.1400            9.5800
# 765837            9.1400            9.5800            8.8400
# 765838            9.5800            8.8400           11.0300
#
#         electricity(t-1)  electricity(t)
# 0                17.3571         17.3571
# 1                17.3571         17.3571
# 2                17.3571         17.3571
# 3                17.3571         17.3571
# 4                17.3571         17.3571
# ...                  ...             ...
# 765834            9.1400          9.5800
# 765835            9.5800          8.8400
# 765836            8.8400         11.0300
# 765837           11.0300          9.7700
# 765838            9.7700         12.7000
#
# [765839 rows x 74 columns]

# %%
val_id_df
# Out:
#         building_id  square_feet(t-6)  air_temperature(t-6)  \
# 0              1311           66794.0                   5.6
# 1              1311           66794.0                   5.6
# 2              1311           66794.0                   5.6
# 3              1311           66794.0                   5.0
# 4              1311           66794.0                   4.4
# ...             ...               ...                   ...
# 173077         1417           40451.0                  -3.3
# 173078         1417           40451.0                  -2.8
# 173079         1417           40451.0                  -1.7
# 173080         1417           40451.0                  -0.6
# 173081         1417           40451.0                   2.2
#
#         dew_temperature(t-6)  sea_level_pressure(t-6)  wind_direction(t-6)  \
# 0                       -0.6                   1019.3                  7.0
# 1                       -0.6                   1019.4                  7.0
# 2                       -1.1                   1019.4                  7.0
# 3                       -2.2                   1019.2                  6.0
# 4                       -2.2                   1018.9                  7.0
# ...                      ...                      ...                  ...
# 173077                  -7.8                   1014.4                  4.0
# 173078                  -7.8                   1013.4                  4.0
# 173079                  -7.2                   1012.3                  4.0
# 173080                  -6.7                   1011.1                  4.0
# 173081                  -7.8                   1009.1                  4.0
#
#         wind_speed(t-6)  pressure_meter(t-6)  month(t-6)  day(t-6)  ...  \
# 0                   2.6                  1.0         1.0       1.0  ...
# 1                   2.6                  1.0         1.0       1.0  ...
# 2                   1.5                  1.0         1.0       1.0  ...
# 3                   3.1                  1.0         1.0       1.0  ...
# 4                   4.1                  1.0         1.0       1.0  ...
# ...                 ...                  ...         ...       ...  ...
# 173077              6.7                  1.0        12.0      31.0  ...
# 173078              5.7                  1.0        12.0      31.0  ...
# 173079              6.7                  1.0        12.0      31.0  ...
# 173080              7.2                  1.0        12.0      31.0  ...
# 173081              7.7                  1.0        12.0      31.0  ...
#
#         day(t-1)  weekday(t-1)  hour(t-1)  electricity(t-6)  electricity(t-5)  \
# 0            1.0           5.0        6.0           26.5716           24.5416
# 1            1.0           6.0        7.0           24.5416           25.4905
# 2            1.0           7.0        8.0           25.4905           26.9095
# 3            1.0           1.0        9.0           26.9095           26.4995
# 4            1.0           2.0       10.0           26.4995           25.3895
# ...          ...           ...        ...               ...               ...
# 173077      31.0           4.0       18.0           92.3000           84.1250
# 173078      31.0           5.0       19.0           84.1250           79.9750
# 173079      31.0           6.0       20.0           79.9750           79.6750
# 173080      31.0           7.0       21.0           79.6750           95.8250
# 173081      31.0           1.0       22.0           95.8250           93.8750
#
#         electricity(t-4)  electricity(t-3)  electricity(t-2)  \
# 0                25.4905           26.9095           26.4995
# 1                26.9095           26.4995           25.3895
# 2                26.4995           25.3895           25.8695
# 3                25.3895           25.8695           27.2795
# 4                25.8695           27.2795           25.5795
# ...                  ...               ...               ...
# 173077           79.9750           79.6750           95.8250
# 173078           79.6750           95.8250           93.8750
# 173079           95.8250           93.8750           88.5000
# 173080           93.8750           88.5000           85.8750
# 173081           88.5000           85.8750           75.3500
#
#         electricity(t-1)  electricity(t)
# 0                25.3895         25.8695
# 1                25.8695         27.2795
# 2                27.2795         25.5795
# 3                25.5795         25.8295
# 4                25.8295         27.6895
# ...                  ...             ...
# 173077           93.8750         88.5000
# 173078           88.5000         85.8750
# 173079           85.8750         75.3500
# 173080           75.3500         85.0000
# 173081           85.0000         79.3500
#
# [173082 rows x 74 columns]

# %%
test_id_df
# Out:
#        building_id  square_feet(t-6)  air_temperature(t-6)  \
# 0             1418           41302.0                   0.0
# 1             1418           41302.0                   0.0
# 2             1418           41302.0                   0.0
# 3             1418           41302.0                   0.0
# 4             1418           41302.0                   0.0
# ...            ...               ...                   ...
# 52206         1447           29775.0                  -3.3
# 52207         1447           29775.0                  -2.8
# 52208         1447           29775.0                  -1.7
# 52209         1447           29775.0                  -0.6
# 52210         1447           29775.0                   2.2
#
#        dew_temperature(t-6)  sea_level_pressure(t-6)  wind_direction(t-6)  \
# 0                 -2.000000                   1019.4                  7.0
# 1                 -2.000000                   1019.4                  7.0
# 2                 -2.000000                   1019.4                  0.0
# 3                 -2.111111                   1019.4                  7.0
# 4                 -2.222222                   1019.4                  7.0
# ...                     ...                      ...                  ...
# 52206             -7.800000                   1014.4                  4.0
# 52207             -7.800000                   1013.4                  4.0
# 52208             -7.200000                   1012.3                  4.0
# 52209             -6.700000                   1011.1                  4.0
# 52210             -7.800000                   1009.1                  4.0
#
#        wind_speed(t-6)  pressure_meter(t-6)  month(t-6)  day(t-6)  ...  \
# 0             4.100000                  1.0         1.0       1.0  ...
# 1             2.600000                  1.0         1.0       1.0  ...
# 2             2.100000                  1.0         1.0       1.0  ...
# 3             2.155556                  1.0         1.0       1.0  ...
# 4             2.211111                  1.0         1.0       1.0  ...
# ...                ...                  ...         ...       ...  ...
# 52206         6.700000                  1.0        12.0      31.0  ...
# 52207         5.700000                  1.0        12.0      31.0  ...
# 52208         6.700000                  1.0        12.0      31.0  ...
# 52209         7.200000                  1.0        12.0      31.0  ...
# 52210         7.700000                  1.0        12.0      31.0  ...
#
#        day(t-1)  weekday(t-1)  hour(t-1)  electricity(t-6)  electricity(t-5)  \
# 0           1.0           3.0        6.0            12.425            12.300
# 1           1.0           4.0        7.0            12.300            12.750
# 2           1.0           5.0        8.0            12.750            12.925
# 3           1.0           6.0        9.0            12.925            12.950
# 4           1.0           7.0       10.0            12.950            13.000
# ...         ...           ...        ...               ...               ...
# 52206      31.0           4.0       18.0           145.750           146.050
# 52207      31.0           5.0       19.0           146.050           146.525
# 52208      31.0           6.0       20.0           146.525           152.725
# 52209      31.0           7.0       21.0           152.725           167.725
# 52210      31.0           1.0       22.0           167.725           170.225
#
#        electricity(t-4)  electricity(t-3)  electricity(t-2)  electricity(t-1)  \
# 0                12.750            12.925            12.950            13.000
# 1                12.925            12.950            13.000            12.950
# 2                12.950            13.000            12.950            12.625
# 3                13.000            12.950            12.625            12.675
# 4                12.950            12.625            12.675            12.575
# ...                 ...               ...               ...               ...
# 52206           146.525           152.725           167.725           170.225
# 52207           152.725           167.725           170.225           167.800
# 52208           167.725           170.225           167.800           168.150
# 52209           170.225           167.800           168.150           164.075
# 52210           167.800           168.150           164.075           158.800
#
#        electricity(t)
# 0              12.950
# 1              12.625
# 2              12.675
# 3              12.575
# 4              12.975
# ...               ...
# 52206         167.800
# 52207         168.150
# 52208         164.075
# 52209         158.800
# 52210         159.575
#
# [52211 rows x 74 columns]

# %%
#generación de los csv con los diferentes datos

train_data.to_csv('./train_data.csv')
val_id_df.to_csv('./validation_data.csv')
test_id_df.to_csv('./test_data.csv')
