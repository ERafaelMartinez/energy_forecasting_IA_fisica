# %% [markdown]
# # 1. Limpieza de los datos

# %%
# !pip install pandasql
# Out:
# Requirement already satisfied: pandasql in /usr/local/lib/python3.6/dist-packages (0.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from pandasql) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pandasql) (1.19.5)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.6/dist-packages (from pandasql) (1.3.23)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->pandasql) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->pandasql) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)

# %%
import pandasql as ps
import pandas as pd
import numpy as np

# %%
#Lectura
b_metadata = pd.read_csv('./building_metadata.csv')
weather_train = pd.read_csv('./weather_train.csv', parse_dates=True, index_col='timestamp')
weather_test = pd.read_csv('./weather_test.csv', parse_dates=True, index_col='timestamp')
meters_train = pd.read_csv('./train.csv')
meters_test = pd.read_csv('./test.csv')

# %% [markdown]
# ## 1.1 Previsualización y Organización de las Tablas

# %% [markdown]
# ### 1.1.1 Metadatos de los edificios

# %%
# Metadatos de los edificios
b_metadata.head()
# Out:
#    site_id  building_id primary_use  square_feet  year_built  floor_count
# 0        0            0   Education         7432      2008.0          NaN
# 1        0            1   Education         2720      2004.0          NaN
# 2        0            2   Education         5376      1991.0          NaN
# 3        0            3   Education        23685      2002.0          NaN
# 4        0            4   Education       116607      1975.0          NaN

# %%
query = ps.sqldf("select primary_use, count(primary_use) from b_metadata group by primary_use")

# %%
query
# Out:
#                       primary_use  count(primary_use)
# 0                       Education                 549
# 1   Entertainment/public assembly                 184
# 2          Food sales and service                   5
# 3                      Healthcare                  23
# 4             Lodging/residential                 147
# 5        Manufacturing/industrial                  12
# 6                          Office                 279
# 7                           Other                  25
# 8                         Parking                  22
# 9                 Public services                 156
# 10              Religious worship                   3
# 11                         Retail                  11
# 12                       Services                  10
# 13             Technology/science                   6
# 14                        Utility                   4
# 15              Warehouse/storage                  13

# %% [markdown]
# Por fines de memoria RAM disponible, decidimos trabajar únicamente con los edificios residenciales, así que extraemos sus metadatos.

# %%
residential_meta = ps.sqldf("select * from b_metadata where primary_use = 'Lodging/residential'")

# %%
residential_meta.isna().value_counts()
# Out:
# site_id  building_id  primary_use  square_feet  year_built  floor_count
# False    False        False        False        False       True           71
#                                                 True        True           58
#                                                 False       False          14
#                                                 True        False           4
# dtype: int64

# %% [markdown]
# Vemos que en la mayor parte de los registros, aunque no toda, se cuenta con la información de número de pisos. Sin embargo todos contienen la información del área en pies cuadrados, la cual corresponde al área bruta del edificio.
# Resulta intuitivo pensar que el área bruta depende proporcionalmente del número de pisos que tiene el edificio en cuestión. De tal manera, no se considerará la información del número de pisos.
#
# Para el caso del año en que se construyó el edificio en cuestión vemos que un 57% de los registros si contienen dicha información y el otro 43% no De tal forma es posible conservar dicha información y los valores nulos mandarlos a 0.
# Es también razonable pensar que por más antiguo que sea un edificio, es normal que reciban ciertas remodelaciones en las distintas instalaciones, sin querer decir que por ser más antiguos tendrán un consumo distinto a los más modernos. Por lo mismo decidimos dejar atrás también dicha información.

# %%
residential_meta = residential_meta.drop( columns=['floor_count', 'year_built'])

# %% [markdown]
# Comprobamos como luce ahora el dataframe con los metadatos

# %%
residential_meta.head()
# Out:
#    site_id  building_id          primary_use  square_feet
# 0        0            6  Lodging/residential        27926
# 1        0           12  Lodging/residential        37100
# 2        0           27  Lodging/residential        59200
# 3        0           33  Lodging/residential        38686
# 4        0           34  Lodging/residential        42731

# %%
residential_meta.to_csv('./residential_metadata.csv')

# %% [markdown]
# ### 1.1.2 Datos del clima de entrenamiento

# %%
weather_train #previsualización de la tabla
# Out:
#                      site_id  air_temperature  cloud_coverage  \
# timestamp
# 2016-01-01 00:00:00        0             25.0             6.0
# 2016-01-01 01:00:00        0             24.4             NaN
# 2016-01-01 02:00:00        0             22.8             2.0
# 2016-01-01 03:00:00        0             21.1             2.0
# 2016-01-01 04:00:00        0             20.0             2.0
# ...                      ...              ...             ...
# 2016-12-31 19:00:00       15              3.0             NaN
# 2016-12-31 20:00:00       15              2.8             2.0
# 2016-12-31 21:00:00       15              2.8             NaN
# 2016-12-31 22:00:00       15              2.2             NaN
# 2016-12-31 23:00:00       15              1.7             NaN
#
#                      dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# timestamp
# 2016-01-01 00:00:00             20.0                NaN              1019.7
# 2016-01-01 01:00:00             21.1               -1.0              1020.2
# 2016-01-01 02:00:00             21.1                0.0              1020.2
# 2016-01-01 03:00:00             20.6                0.0              1020.1
# 2016-01-01 04:00:00             20.0               -1.0              1020.0
# ...                              ...                ...                 ...
# 2016-12-31 19:00:00             -8.0                NaN                 NaN
# 2016-12-31 20:00:00             -8.9                NaN              1007.4
# 2016-12-31 21:00:00             -7.2                NaN              1007.5
# 2016-12-31 22:00:00             -6.7                NaN              1008.0
# 2016-12-31 23:00:00             -5.6               -1.0              1008.5
#
#                      wind_direction  wind_speed
# timestamp
# 2016-01-01 00:00:00             0.0         0.0
# 2016-01-01 01:00:00            70.0         1.5
# 2016-01-01 02:00:00             0.0         0.0
# 2016-01-01 03:00:00             0.0         0.0
# 2016-01-01 04:00:00           250.0         2.6
# ...                             ...         ...
# 2016-12-31 19:00:00           180.0         5.7
# 2016-12-31 20:00:00           180.0         7.7
# 2016-12-31 21:00:00           180.0         5.1
# 2016-12-31 22:00:00           170.0         4.6
# 2016-12-31 23:00:00           180.0         8.8
#
# [139773 rows x 8 columns]

# %% [markdown]
# Vemos qué tantos valores nulos tenemos por cada uno de los sitios y nos enfrentamos al problema de cómo llenar los valores faltantes.
#
# El siguiente análisis pretende resolver dicha interrogante para tomar decisiones al respecto. El análisis se enfoca principalmente en las variables climáticas de nubosidad y precipitación, pues son las más ausentes en los datos como se comprueba a continuación.

# %%
sitios = ps.sqldf('select site_id from weather_train group by site_id') #obtenemos un df con los sitios

# %%
for sitio in sitios.site_id:
    local_weather = ps.sqldf("select * from weather_train where site_id = {}".format(sitio))
    print('-'*50)
    print('Sitio {}\n'.format(sitio))
    for attribute in local_weather.columns:
        try:
            percentage = int(local_weather[attribute].isna().value_counts().loc[False])*100/local_weather.shape[0]
            print('\n Para {} SE TIENE el {:.2f}% de los datos.'.format(attribute, percentage))
            try:
                zeros = int(local_weather[attribute].value_counts().loc[0.0])*100/local_weather[attribute].isna().value_counts().loc[False]
                print('El {:.2f}% de los valores existentes son 0.'.format(zeros))
                if attribute == 'precip_depth_1_hr' or attribute == 'cloud_coverage':
                    print('Probabilidad de que el valor faltante sea una falla y no 0 es: {:.2f}.\n'.format(zeros/percentage))
            except:
                print('No tiene valores en 0.')
                if attribute == 'precip_depth_1_hr' or attribute == 'cloud_coverage':
                    print('El valor faltante es  probablemente 0.')
        except:
            percentage = int(local_weather[attribute].isna().value_counts().loc[True])*100/8784
            print('\n {} esta VACIO.'.format(attribute))
            print('No hay medidor.')
# Out:
# --------------------------------------------------
# Sitio 0
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# El 100.00% de los valores existentes son 0.
#
#  Para air_temperature SE TIENE el 99.97% de los datos.
# No tiene valores en 0.
#
#  Para cloud_coverage SE TIENE el 56.40% de los datos.
# El 17.76% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.31.
#
#
#  Para dew_temperature SE TIENE el 99.97% de los datos.
# El 0.30% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 99.99% de los datos.
# El 90.49% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.91.
#
#
#  Para sea_level_pressure SE TIENE el 99.03% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 97.15% de los datos.
# El 12.01% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 100.00% de los datos.
# El 11.67% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 1
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 99.99% de los datos.
# El 0.09% de los valores existentes son 0.
#
#  Para cloud_coverage SE TIENE el 19.41% de los datos.
# El 99.06% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 5.10.
#
#
#  Para dew_temperature SE TIENE el 99.99% de los datos.
# El 0.31% de los valores existentes son 0.
#
#  precip_depth_1_hr esta VACIO.
# No hay medidor.
#
#  Para sea_level_pressure SE TIENE el 99.41% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 99.97% de los datos.
# El 0.30% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 100.00% de los datos.
# El 0.30% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 2
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 99.99% de los datos.
# No tiene valores en 0.
#
#  Para cloud_coverage SE TIENE el 73.20% de los datos.
# El 37.33% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.51.
#
#
#  Para dew_temperature SE TIENE el 99.99% de los datos.
# El 2.81% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 99.25% de los datos.
# El 97.49% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.98.
#
#
#  Para sea_level_pressure SE TIENE el 99.50% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 93.27% de los datos.
# El 14.62% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 99.94% de los datos.
# El 13.65% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 3
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 99.95% de los datos.
# El 0.75% de los valores existentes son 0.
#
#  Para cloud_coverage SE TIENE el 58.52% de los datos.
# El 17.87% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.31.
#
#
#  Para dew_temperature SE TIENE el 99.93% de los datos.
# El 1.45% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 99.58% de los datos.
# El 87.25% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.88.
#
#
#  Para sea_level_pressure SE TIENE el 98.20% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 98.26% de los datos.
# El 7.07% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 99.95% de los datos.
# El 6.95% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 4
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para cloud_coverage SE TIENE el 51.84% de los datos.
# El 25.98% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.50.
#
#
#  Para dew_temperature SE TIENE el 99.98% de los datos.
# El 0.30% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 85.01% de los datos.
# El 92.35% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 1.09.
#
#
#  Para sea_level_pressure SE TIENE el 99.17% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 98.80% de los datos.
# El 11.79% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 100.00% de los datos.
# El 11.65% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 5
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 99.98% de los datos.
# El 0.47% de los valores existentes son 0.
#
#  Para cloud_coverage SE TIENE el 31.13% de los datos.
# El 96.77% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 3.11.
#
#
#  Para dew_temperature SE TIENE el 99.98% de los datos.
# El 2.97% de los valores existentes son 0.
#
#  precip_depth_1_hr esta VACIO.
# No hay medidor.
#
#  sea_level_pressure esta VACIO.
# No hay medidor.
#
#  Para wind_direction SE TIENE el 96.63% de los datos.
# El 0.07% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 99.97% de los datos.
# El 0.07% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 6
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 99.89% de los datos.
# El 0.84% de los valores existentes son 0.
#
#  Para cloud_coverage SE TIENE el 65.93% de los datos.
# El 81.64% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 1.24.
#
#
#  Para dew_temperature SE TIENE el 99.89% de los datos.
# El 1.46% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 100.00% de los datos.
# El 88.99% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.89.
#
#
#  Para sea_level_pressure SE TIENE el 98.01% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 91.13% de los datos.
# El 30.39% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 99.56% de los datos.
# El 27.82% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 7
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 100.00% de los datos.
# El 0.30% de los valores existentes son 0.
#
#  cloud_coverage esta VACIO.
# No hay medidor.
#
#  Para dew_temperature SE TIENE el 99.73% de los datos.
# El 0.30% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 8.49% de los datos.
# No tiene valores en 0.
# El valor faltante es  probablemente 0.
#
#  Para sea_level_pressure SE TIENE el 99.91% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para wind_speed SE TIENE el 100.00% de los datos.
# El 2.24% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 8
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 99.97% de los datos.
# No tiene valores en 0.
#
#  Para cloud_coverage SE TIENE el 56.40% de los datos.
# El 17.76% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.31.
#
#
#  Para dew_temperature SE TIENE el 99.97% de los datos.
# El 0.30% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 99.99% de los datos.
# El 90.49% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.91.
#
#
#  Para sea_level_pressure SE TIENE el 99.03% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 97.15% de los datos.
# El 12.01% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 100.00% de los datos.
# El 11.67% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 9
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 99.94% de los datos.
# El 0.07% de los valores existentes son 0.
#
#  Para cloud_coverage SE TIENE el 60.62% de los datos.
# El 79.26% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 1.31.
#
#
#  Para dew_temperature SE TIENE el 99.92% de los datos.
# El 1.11% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 99.92% de los datos.
# El 91.55% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.92.
#
#
#  Para sea_level_pressure SE TIENE el 97.28% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 70.87% de los datos.
# El 33.88% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 98.90% de los datos.
# El 24.28% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 10
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 99.73% de los datos.
# El 1.75% de los valores existentes son 0.
#
#  Para cloud_coverage SE TIENE el 72.10% de los datos.
# El 89.73% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 1.24.
#
#
#  Para dew_temperature SE TIENE el 99.69% de los datos.
# El 5.01% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 99.69% de los datos.
# El 90.19% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.90.
#
#
#  Para sea_level_pressure SE TIENE el 98.39% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 93.92% de los datos.
# El 12.10% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 98.82% de los datos.
# El 11.50% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 11
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 100.00% de los datos.
# El 0.30% de los valores existentes son 0.
#
#  cloud_coverage esta VACIO.
# No hay medidor.
#
#  Para dew_temperature SE TIENE el 99.73% de los datos.
# El 0.30% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 8.49% de los datos.
# No tiene valores en 0.
# El valor faltante es  probablemente 0.
#
#  Para sea_level_pressure SE TIENE el 99.91% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para wind_speed SE TIENE el 100.00% de los datos.
# El 2.24% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 12
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 100.00% de los datos.
# El 0.15% de los valores existentes son 0.
#
#  Para cloud_coverage SE TIENE el 99.33% de los datos.
# El 0.54% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.01.
#
#
#  Para dew_temperature SE TIENE el 100.00% de los datos.
# El 0.46% de los valores existentes son 0.
#
#  precip_depth_1_hr esta VACIO.
# No hay medidor.
#
#  Para sea_level_pressure SE TIENE el 99.36% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 99.99% de los datos.
# El 0.73% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 100.00% de los datos.
# El 0.73% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 13
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 99.99% de los datos.
# El 1.46% de los valores existentes son 0.
#
#  Para cloud_coverage SE TIENE el 51.06% de los datos.
# El 31.22% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.61.
#
#
#  Para dew_temperature SE TIENE el 99.99% de los datos.
# El 2.08% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 99.86% de los datos.
# El 85.32% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.85.
#
#
#  Para sea_level_pressure SE TIENE el 98.63% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 97.53% de los datos.
# El 6.26% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 99.99% de los datos.
# El 6.11% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 14
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 99.99% de los datos.
# El 1.45% de los valores existentes son 0.
#
#  Para cloud_coverage SE TIENE el 62.28% de los datos.
# El 83.17% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 1.34.
#
#
#  Para dew_temperature SE TIENE el 99.99% de los datos.
# El 1.73% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 99.65% de los datos.
# El 88.81% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 0.89.
#
#
#  Para sea_level_pressure SE TIENE el 98.75% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 96.70% de los datos.
# El 13.95% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 99.74% de los datos.
# El 13.53% de los valores existentes son 0.
# --------------------------------------------------
# Sitio 15
#
#
#  Para timestamp SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para site_id SE TIENE el 100.00% de los datos.
# No tiene valores en 0.
#
#  Para air_temperature SE TIENE el 100.00% de los datos.
# El 1.70% de los valores existentes son 0.
#
#  Para cloud_coverage SE TIENE el 47.97% de los datos.
# El 65.80% de los valores existentes son 0.
# Probabilidad de que el valor faltante sea una falla y no 0 es: 1.37.
#
#
#  Para dew_temperature SE TIENE el 99.96% de los datos.
# El 2.17% de los valores existentes son 0.
#
#  Para precip_depth_1_hr SE TIENE el 20.14% de los datos.
# No tiene valores en 0.
# El valor faltante es  probablemente 0.
#
#  Para sea_level_pressure SE TIENE el 93.98% de los datos.
# No tiene valores en 0.
#
#  Para wind_direction SE TIENE el 97.14% de los datos.
# El 11.19% de los valores existentes son 0.
#
#  Para wind_speed SE TIENE el 99.67% de los datos.
# El 10.92% de los valores existentes son 0.

# %% [markdown]
# Se observa que en la mayor parte de los sitios hacen falta los datos de covertura de nubes y de precipitación. Debido a que no es enteramente claro el motivo del porqué faltan dichas cantidades de datos ni se indican en la [página de la competencia](https://www.kaggle.com/c/ashrae-energy-prediction/overview), hemos decidido dejar atras dicha información, mientras que para el sitio 5, que no tiene medidor para la presión atmosférica, se rellenarán los valores con 0 y se agregará una columna adicional que indique para cada uno de los sitios si se contaba con dicha información con un 1 y si no, con un 0.
#
# Los valores faltantes de las demás columnas se completan por medio de interpolaciones.

# %%
#se ajusta el dataframe con las fechas para cada uno de los sitios
weather_train = pd.read_csv('./weather_train.csv', parse_dates=True, index_col='timestamp')
weather_train = weather_train.drop( columns=['cloud_coverage', 'precip_depth_1_hr'])

# %%
weather_clean_train = pd.DataFrame()
for sitio in sitios.site_id:
    print('Limpiando datos del clima para el sitio {}'.format(sitio))
    local_weather = ps.sqldf("select * from weather_train where site_id = {}".format(sitio)) #read df for each site
    local_weather = local_weather.replace(-1,np.nan)
    local_weather['timestamp'] = pd.to_datetime(local_weather['timestamp'], infer_datetime_format=True) #parse dates
    local_weather = local_weather.set_index('timestamp') #date as index

    local_weather = local_weather.asfreq('H') #set hourly frequency to dataframe

    #atributo que indica si funciona bien o no el medidor de presión
    if sitio == 5 :
        local_weather['pressure_meter'] = np.zeros(local_weather.shape[0]).tolist()
    else:
        local_weather['pressure_meter'] = np.ones(local_weather.shape[0]).tolist()


    #se llenan con 0 los datos del medidor de pressión para el sitio 5.
    if sitio == 5:
        local_weather['sea_level_pressure'] = local_weather['sea_level_pressure'].fillna(0.0)

    #se interpolan el resto de los datos
    local_weather = local_weather.interpolate(method='time', limit_direction='both')
    #se vuelven a juntar los datos del clima limpios para cada uno de los sitios
    weather_clean_train = pd.concat([weather_clean_train, local_weather])
# Out:
# Limpiando datos del clima para el sitio 0
# Limpiando datos del clima para el sitio 1
# Limpiando datos del clima para el sitio 2
# Limpiando datos del clima para el sitio 3
# Limpiando datos del clima para el sitio 4
# Limpiando datos del clima para el sitio 5
# Limpiando datos del clima para el sitio 6
# Limpiando datos del clima para el sitio 7
# Limpiando datos del clima para el sitio 8
# Limpiando datos del clima para el sitio 9
# Limpiando datos del clima para el sitio 10
# Limpiando datos del clima para el sitio 11
# Limpiando datos del clima para el sitio 12
# Limpiando datos del clima para el sitio 13
# Limpiando datos del clima para el sitio 14
# Limpiando datos del clima para el sitio 15

# %% [markdown]
# Se comprueba que la limpia de los datos ha sido correcta.

# %%
weather_clean_train.isnull().value_counts()
# Out:
# site_id  air_temperature  dew_temperature  sea_level_pressure  wind_direction  wind_speed  pressure_meter
# False    False            False            False               False           False       False             140537
# dtype: int64

# %% [markdown]
# A continuación se transforma la variable de la dirección del viento a categórica. Así mismo se agregan como atributos el día de la semana, hora del día, día del mes y el mes.

# %%
def weekday_categorical_int(data, initial_day = 1):
    '''
    Create a categorical value for the number of the day of the week. 1 = monday, 
    2 = tuesday and so on. 
    '''
    day = [initial_day]
    
    for i in range(data.shape[0] - 1):
        if day[i] == 7:
            num_day = 0
        else:
            num_day = day[i]
        day.append(num_day + 1)
    return day

def wind_dir_categorical_int(data):
    wind_dir = data['wind_direction'].astype('float32').tolist()
    for i in range(len(wind_dir)):
        x = wind_dir[i]
        if 22.5 <= x < 67.5:
            wind_dir[i] = 1
        elif 67.5 <= x < 112.5:
            wind_dir[i] = 2
        elif 112.5 <= x < 157.5:
            wind_dir[i] = 3
        elif 157.5 <= x < 202.5:
            wind_dir[i] = 4
        elif 202.5 <= x < 247.5:
            wind_dir[i] = 5
        elif 247.5 <= x < 292.5:
            wind_dir[i] = 6
        elif 292.5 <= x < 337.5:
            wind_dir[i] = 7
        else:
            wind_dir[i] = 0
    return wind_dir

# %%
#adding columns with datetime data
weather_clean_train['month'] = [d.month for d in weather_clean_train.index]
weather_clean_train['day'] = [d.day for d in weather_clean_train.index]
weather_clean_train['weekday'] = weekday_categorical_int(weather_clean_train, 5)
weather_clean_train['hour'] = [d.hour for d in weather_clean_train.index]
#overwriting wind_dir column
weather_clean_train['wind_direction'] = wind_dir_categorical_int(weather_clean_train)

# %% [markdown]
# Sería posible codificar dichas variables categóricas en One Hot como hicimos anteriormente. Sin embargo, para no incrmenetar excesivamente la dimensionalidad de los datos, decidimos dejarla con la codificación actual (por enteros/labels).

# %%
weather_clean_train.head()
# Out:
#                      site_id  air_temperature  dew_temperature  \
# timestamp
# 2016-01-01 00:00:00      0.0             25.0             20.0
# 2016-01-01 01:00:00      0.0             24.4             21.1
# 2016-01-01 02:00:00      0.0             22.8             21.1
# 2016-01-01 03:00:00      0.0             21.1             20.6
# 2016-01-01 04:00:00      0.0             20.0             20.0
#
#                      sea_level_pressure  wind_direction  wind_speed  \
# timestamp
# 2016-01-01 00:00:00              1019.7               0         0.0
# 2016-01-01 01:00:00              1020.2               2         1.5
# 2016-01-01 02:00:00              1020.2               0         0.0
# 2016-01-01 03:00:00              1020.1               0         0.0
# 2016-01-01 04:00:00              1020.0               6         2.6
#
#                      pressure_meter  month  day  weekday  hour
# timestamp
# 2016-01-01 00:00:00             1.0      1    1        5     0
# 2016-01-01 01:00:00             1.0      1    1        6     1
# 2016-01-01 02:00:00             1.0      1    1        7     2
# 2016-01-01 03:00:00             1.0      1    1        1     3
# 2016-01-01 04:00:00             1.0      1    1        2     4

# %%
weather_clean_train.shape
# Out:
# (140537, 11)

# %%
weather_clean_train.to_csv('./weather_clean_train.csv')

# %% [markdown]
# ### 1.1.4 Test and Train Labels

# %%
import pandas as pd
import pandasql as ps
import numpy as np

# %% [markdown]
# Partiendo de la suposición de que dichos csv están completos, procedemos a la extracción de los datos con los edificios residenciales.

# %%
meters_train = pd.read_csv('./train.csv')
residential_meta = pd.read_csv('./residential_metadata.csv')

# %%
buildings_id_res = ps.sqldf("select building_id from residential_meta") #id con los edificios residenciales

# %%
meters_train.head() #tabla con información sobre medidores
# Out:
#    building_id  meter            timestamp  meter_reading
# 0            0      0  2016-01-01 00:00:00            0.0
# 1            1      0  2016-01-01 00:00:00            0.0
# 2            2      0  2016-01-01 00:00:00            0.0
# 3            3      0  2016-01-01 00:00:00            0.0
# 4            4      0  2016-01-01 00:00:00            0.0

# %%
#Filtrado de la información de solo los medidores 0 
meter_0 = ps.sqldf("select * from meters_train where meter = 0")

# %%
#Extrayendo únicamente los edificios residenciales
meter_0_res = ps.sqldf("select * from meter_0 where building_id in (select * from buildings_id_res)")

# %%
meter_0_res['electricity'] = meter_0_res['meter_reading'].values.tolist()
e_load =  meter_0_res.drop(columns=['meter', 'meter_reading'])
e_load
# Out:
#          building_id            timestamp  electricity
# 0                  6  2016-01-01 00:00:00        0.000
# 1                 12  2016-01-01 00:00:00        0.000
# 2                 27  2016-01-01 00:00:00        0.000
# 3                 33  2016-01-01 00:00:00        0.000
# 4                 34  2016-01-01 00:00:00        0.000
# ...              ...                  ...          ...
# 1229077         1422  2016-12-31 23:00:00        9.575
# 1229078         1423  2016-12-31 23:00:00        9.400
# 1229079         1424  2016-12-31 23:00:00       16.500
# 1229080         1440  2016-12-31 23:00:00      154.750
# 1229081         1447  2016-12-31 23:00:00      159.575
#
# [1229082 rows x 3 columns]

# %%
e_load.to_csv('./electric_load_residential.csv')

# %% [markdown]
# ## 1.2 Juntando las tablas

# %% [markdown]
# Nos interesa juntar en una sola tabla la información de los medidores, así como los datos del clima para poder insertarlos al sistema como un solo vector de entrada.

# %%
residential_meta = pd.read_csv('./residential_metadata.csv')
weather_clean_train = pd.read_csv('./weather_clean_train.csv')
electric_load = pd.read_csv('./electric_load_residential.csv')

# %%
residential_meta = residential_meta.drop(columns = ['Unnamed: 0','primary_use'])
electric_load = electric_load.drop(columns = ['Unnamed: 0'])
residential_meta
# Out:
#      site_id  building_id  square_feet
# 0          0            6        27926
# 1          0           12        37100
# 2          0           27        59200
# 3          0           33        38686
# 4          0           34        42731
# ..       ...          ...          ...
# 142       15         1422        19876
# 143       15         1423        18277
# 144       15         1424        24103
# 145       15         1440       150294
# 146       15         1447        29775
#
# [147 rows x 3 columns]

# %%
#juntando los datos del medidor con los metadatos del edificio.
input_data = electric_load.merge(residential_meta, on='building_id')

# %%
input_data
# Out:
#          building_id            timestamp  electricity  site_id  square_feet
# 0                  6  2016-01-01 00:00:00        0.000        0        27926
# 1                  6  2016-01-01 01:00:00        0.000        0        27926
# 2                  6  2016-01-01 02:00:00        0.000        0        27926
# 3                  6  2016-01-01 03:00:00        0.000        0        27926
# 4                  6  2016-01-01 04:00:00        0.000        0        27926
# ...              ...                  ...          ...      ...          ...
# 1229077          647  2016-12-31 19:00:00       19.296        4        86959
# 1229078          647  2016-12-31 20:00:00       20.078        4        86959
# 1229079          647  2016-12-31 21:00:00       19.654        4        86959
# 1229080          647  2016-12-31 22:00:00       19.664        4        86959
# 1229081          647  2016-12-31 23:00:00       19.548        4        86959
#
# [1229082 rows x 5 columns]

# %%
#juntando los datos del clima con el resto
input_data = input_data.merge(weather_clean_train, on = ['timestamp', 'site_id'])

# %%
input_data
# Out:
#          building_id            timestamp  electricity  site_id  square_feet  \
# 0                  6  2016-01-01 00:00:00        0.000        0        27926
# 1                 12  2016-01-01 00:00:00        0.000        0        37100
# 2                 27  2016-01-01 00:00:00        0.000        0        59200
# 3                 33  2016-01-01 00:00:00        0.000        0        38686
# 4                 34  2016-01-01 00:00:00        0.000        0        42731
# ...              ...                  ...          ...      ...          ...
# 1229003         1422  2016-06-26 18:00:00        5.300       15        19876
# 1229004         1423  2016-06-26 18:00:00       12.725       15        18277
# 1229005         1424  2016-06-26 18:00:00       24.250       15        24103
# 1229006         1440  2016-06-26 18:00:00      274.600       15       150294
# 1229007         1447  2016-06-26 18:00:00      157.225       15        29775
#
#          air_temperature  dew_temperature  sea_level_pressure  wind_direction  \
# 0                   25.0             20.0              1019.7               0
# 1                   25.0             20.0              1019.7               0
# 2                   25.0             20.0              1019.7               0
# 3                   25.0             20.0              1019.7               0
# 4                   25.0             20.0              1019.7               0
# ...                  ...              ...                 ...             ...
# 1229003             30.6             15.6              1020.3               4
# 1229004             30.6             15.6              1020.3               4
# 1229005             30.6             15.6              1020.3               4
# 1229006             30.6             15.6              1020.3               4
# 1229007             30.6             15.6              1020.3               4
#
#          wind_speed  pressure_meter  month  day  weekday  hour
# 0               0.0             1.0      1    1        5     0
# 1               0.0             1.0      1    1        5     0
# 2               0.0             1.0      1    1        5     0
# 3               0.0             1.0      1    1        5     0
# 4               0.0             1.0      1    1        5     0
# ...             ...             ...    ...  ...      ...   ...
# 1229003         4.1             1.0      6   26        7    18
# 1229004         4.1             1.0      6   26        7    18
# 1229005         4.1             1.0      6   26        7    18
# 1229006         4.1             1.0      6   26        7    18
# 1229007         4.1             1.0      6   26        7    18
#
# [1229008 rows x 15 columns]

# %%
#se ordenan por número de edificio
input_ordered = ps.sqldf("select * from input_data order by building_id desc, timestamp asc")
input_ordered
# Out:
#          building_id            timestamp  electricity  site_id  square_feet  \
# 0               1447  2016-01-01 01:00:00      156.650       15        29775
# 1               1447  2016-01-01 02:00:00      157.575       15        29775
# 2               1447  2016-01-01 03:00:00      154.925       15        29775
# 3               1447  2016-01-01 04:00:00      156.075       15        29775
# 4               1447  2016-01-01 05:00:00      154.500       15        29775
# ...              ...                  ...          ...      ...          ...
# 1229003            6  2016-12-31 19:00:00      264.970        0        27926
# 1229004            6  2016-12-31 20:00:00      265.379        0        27926
# 1229005            6  2016-12-31 21:00:00      263.741        0        27926
# 1229006            6  2016-12-31 22:00:00      258.827        0        27926
# 1229007            6  2016-12-31 23:00:00      259.646        0        27926
#
#          air_temperature  dew_temperature  sea_level_pressure  wind_direction  \
# 0                    0.0        -2.000000              1019.4               7
# 1                    0.0        -2.000000              1019.4               7
# 2                    0.0        -2.000000              1019.4               0
# 3                    0.0        -2.111111              1019.4               7
# 4                    0.0        -2.222222              1019.4               7
# ...                  ...              ...                 ...             ...
# 1229003             22.8        10.000000              1021.7               3
# 1229004             23.3         8.900000              1021.0               4
# 1229005             23.3        10.000000              1021.1               3
# 1229006             22.8        10.000000              1021.1               4
# 1229007             20.6        10.000000              1021.1               0
#
#          wind_speed  pressure_meter  month  day  weekday  hour
# 0          4.100000             1.0      1    1        5     1
# 1          2.600000             1.0      1    1        6     2
# 2          2.100000             1.0      1    1        7     3
# 3          2.155556             1.0      1    1        1     4
# 4          2.211111             1.0      1    1        2     5
# ...             ...             ...    ...  ...      ...   ...
# 1229003    5.700000             1.0     12   31        6    19
# 1229004    4.100000             1.0     12   31        7    20
# 1229005    4.100000             1.0     12   31        1    21
# 1229006    3.100000             1.0     12   31        2    22
# 1229007    0.000000             1.0     12   31        3    23
#
# [1229008 rows x 15 columns]

# %%
input_ordered.to_csv('./data_ordered.csv')
